# %% [markdown]
# ### Задание 1

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7]
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]

plt.plot(x, y, color='salmon')
plt.show()

# %%
plt.scatter(x, y, color='salmon')
plt.show()

# %% [markdown]
# ### Задание 2

# %%
t = np.linspace(0, 10, num=51)
f = np.cos(t)

plt.plot(t, f, color='lightgreen')

plt.xlabel("Значения t")
plt.ylabel("Значения f")
plt.title('График f(t)')
plt.xlim([0.5, 9.5])
plt.ylim([-2.5, 2.5])

plt.show()

# %% [markdown]
# ### Задание 3

# %%
x = np.linspace(-3, 3, num=51)
y1 = x ** 2
y2 = 2 * x + 0.5
y3 = -3 * x - 1.5
y4 = np.sin(x)

fig, ax = plt.subplots(nrows=2, ncols=2)
ax1, ax2, ax3, ax4 = ax.flatten()

fig.set_size_inches(10, 8) # я сделала числа побольше потому что при 8, 6 графики все равно были маленькими
fig.subplots_adjust(wspace=0.3, hspace=0.3)

# заметка для себя))) вместо ax1 можно:
# ax[0, 0].plot(x, y1)
# ax[0, 0].set_title("x^2") итд

ax1.plot(x, y1, color='mediumorchid')
# не поняла про ограничение по оси x [-5, 5], если у нас [-3, 3]
ax1.set_title("x^2")

ax2.plot(x, y2, color='coral')
ax2.set_title("2x + 0.5")

ax3.plot(x, y3, color='seagreen')
ax3.set_title("-3x - 1.5")

ax4.plot(x, y4, color='royalblue')
ax4.set_title("sin(x)")

plt.show()

# %% [markdown]
# ### Задание 4

# %%
import pandas as pd

ccfd = pd.read_csv('creditcard.csv')
ccfd.info() # проверяем на отсутствие пропусков
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
ccfd['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
plt.style.use('fivethirtyeight')

ccfd['Class'].hist(figsize=(4, 4), bins=20)
# как сделать только 0 и 1 без десятых???
plt.show()

# %%
ccfd['Class'].hist(figsize=(4, 4), bins=20);
plt.yscale('log')

# %%
df1 = ccfd.query('Class == 1').V1
df0 = ccfd.query('Class == 0').V1

fig, ax = plt.subplots()

ax.hist(df0, bins=20, density = True, color = 'grey', alpha = 0.5, label = 'Class 0')
ax.hist(df1, bins=20, density = True, color = 'red', alpha = 0.5, label = 'Class 1')
ax.set_xlabel('V1')
ax.legend()

plt.show()

# %%
# это неправильно, но я оставила, потому что мне интересно узнать как получился такой график)))))
fig, ax = plt.subplots()

ax.plot(ccfd[ccfd['Class'] == 1]['V1'], alpha = 0.5)
ax.plot(ccfd[ccfd['Class'] == 0]['V1'], alpha = 0.5)
plt.show()
